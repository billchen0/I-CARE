# %%
from pathlib import Path
import numpy as np

root_path = Path("/media/hdd1/i-care/processed/")

# %%
# Select one patient to construct the pipeline
p_data = root_path / "0326"

# %%
# Loop through the hourly segments of EEG data
for hr_seg in sorted(p_data.iterdir()):
    # Read in the segment
    eeg_data = np.load(hr_seg)
    # Loop through each segment with a 5 minute window
    for start in range(0, eeg_data.shape[0], 5*60*100):
        end = start + 5*60*100
        segment = eeg_data[start:end, :]
# Out:
# 0
# 30000
# 30000
# 60000
# 60000
# 90000
# 90000
# 120000
# 120000
# 150000
# 0
# 30000
# 30000
# 60000
# 60000
# 90000
# 90000
# 120000
# 120000
# 150000
# 150000
# 180000
# 180000
# 210000
# 210000
# 240000
# 240000
# 270000
# 270000
# 300000
# 300000
# 330000
# 330000
# 360000
# 0
# 30000
# 30000
# 60000
# 60000
# 90000
# 90000
# 120000
# 0
# 30000
# 30000
# 60000
# 60000
# 90000
# 90000
# 120000
# 120000
# 150000
# 150000
# 180000
# 180000
# 210000
# 210000
# 240000
# 0
# 30000
# 30000
# 60000
# 60000
# 90000
# 90000
# 120000
# 120000
# 150000
# 150000
# 180000
# 180000
# 210000
# 210000
# 240000
# 240000
# 270000
# 270000
# 300000
# 300000
# 330000
# 330000
# 360000
# 0
# 30000
# 30000
# 60000
# 60000
# 90000
# 90000
# 120000
# 120000
# 150000
# 150000
# 180000
# 180000
# 210000
# 210000
# 240000
# 240000
# 270000
# 270000
# 300000
# 300000
# 330000
# 330000
# 360000
# 0
# 30000
# 30000
# 60000
# 60000
# 90000
# 90000
# 120000
# 120000
# 150000
# 150000
# 180000
# 180000
# ...
