# %%
# %reload_ext autoreload
# %autoreload 2
from pathlib import Path
import neurokit2 as nk
import numpy as np
import sys
sys.path.append("..")
from feature_extraction import extract_features

root_path = Path("/media/hdd1/i-care/processed/")

# %%
# Select one patient to construct the pipeline
p_data = root_path / "0326"

# %%
# Loop through the hourly segments of EEG data
for hr_seg in sorted(p_data.iterdir()):
    # Read in the segment
    eeg_data = np.load(hr_seg)
    total_samp = eeg_data.shape[0]
    window_samp = 5*60*100
    # Loop through each segment with a 5 minute window
    for start in range(0, eeg_data.shape[0], window_samp):
        end = start + window_samp
        # Drop segments that don't have full length
        if end <= total_samp:
            segment = eeg_data[start:end, :]
        # Extract features from the segment
        feature = extract_features(segment)
        print(feature)
# Out:
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# (8,)
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/bc299/miniconda3/envs/icare/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2210231/2045205668.py", line 14, in <module>
# ...

# %%
feature_path = Path("/media/hdd1/i-care/features/0725/manual-features.npy")

# %%
features = np.load(feature_path)

# %%
features
# Out:
# array([[0.08287591, 0.011049  , 0.00749309, ..., 4.53138471, 0.51779825,
#         0.5973316 ],
#        [0.08936362, 0.01017039, 0.00722358, ..., 5.35356388, 0.50709298,
#         0.66699719],
#        [0.08237204, 0.01078457, 0.00727491, ..., 5.21201269, 0.53025789,
#         0.65204514],
#        ...,
#        [0.10624904, 0.01975982, 0.0054489 , ..., 5.1993345 , 0.19887193,
#         0.61979936],
#        [0.09627941, 0.01713625, 0.00931709, ..., 5.44770204, 0.24409123,
#         0.65964611],
#        [0.09627941, 0.01713625, 0.00931709, ..., 5.44770204, 0.24409123,
#         0.65964611]])
